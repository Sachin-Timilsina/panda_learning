# %%
import pandas as pd

df = pd.read_csv("practice.csv")

group_by_frame = df.groupby('Industry_name_NZSIOC')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File D:\Sachin Timilsina\AI_ML\Panda Learning\Panda Lessons\pandas_learning_environment\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File D:\Sachin Timilsina\AI_ML\Panda Learning\Panda Lessons\pandas_learning_environment\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# ...
