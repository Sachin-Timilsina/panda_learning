# %% [markdown]
# # Data Analysis On Depression Student Dataset

# %% [markdown]
# ### Goals & Primary Questions:
# - Understand the factors that contribute to symptoms of despression among students.
# - How do dietary habits relate to mental well-being?
# - Is there a relationship between sleep duration and mental health distress?

# %%
print(df.columns)
print(df.dtypes)
# Out:
# Index(['Gender', 'Age', 'Academic Pressure', 'Study Satisfaction',
#        'Sleep Duration', 'Dietary Habits',
#        'Have you ever had suicidal thoughts ?', 'Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')
# Gender                                    object
# Age                                        int64
# Academic Pressure                        float64
# Study Satisfaction                       float64
# Sleep Duration                            object
# Dietary Habits                            object
# Have you ever had suicidal thoughts ?     object
# Study Hours                                int64
# Financial Stress                           int64
# Family History of Mental Illness          object
# Depression                                object
# dtype: object

# %%
import pandas as pd

df = pd.read_csv('Depression Student Dataset.csv')

df.head()
# Out:
#    Gender  Age  Academic Pressure  Study Satisfaction     Sleep Duration  \
# 0    Male   28                2.0                 4.0          7-8 hours
# 1    Male   28                4.0                 5.0          5-6 hours
# 2    Male   25                1.0                 3.0          5-6 hours
# 3    Male   23                1.0                 4.0  More than 8 hours
# 4  Female   31                1.0                 5.0  More than 8 hours
#
#   Dietary Habits Have you ever had suicidal thoughts ?  Study Hours  \
# 0       Moderate                                   Yes            9
# 1        Healthy                                   Yes            7
# 2      Unhealthy                                   Yes           10
# 3      Unhealthy                                   Yes            7
# 4        Healthy                                   Yes            4
#
#    Financial Stress Family History of Mental Illness Depression
# ...

# %%
df.rename(columns={'Have you ever had suicidal thoughts ?':'Suicidal Thoughts'}, inplace=True)
df.rename(columns={'Family History of Mental Illness':'Family History'}, inplace=True)
df.head()
# Out:
#    Gender  Age  Academic Pressure  Study Satisfaction     Sleep Duration  \
# 0    Male   28                2.0                 4.0          7-8 hours
# 1    Male   28                4.0                 5.0          5-6 hours
# 2    Male   25                1.0                 3.0          5-6 hours
# 3    Male   23                1.0                 4.0  More than 8 hours
# 4  Female   31                1.0                 5.0  More than 8 hours
#
#   Dietary Habits Suicidal Thoughts  Study Hours  Financial Stress  \
# 0       Moderate               Yes            9                 2
# 1        Healthy               Yes            7                 1
# 2      Unhealthy               Yes           10                 4
# 3      Unhealthy               Yes            7                 2
# 4        Healthy               Yes            4                 2
#
#   Family History Depression
# 0            Yes         No
# 1            Yes         No
# 2             No        Yes
# ...

# %%
print(df.columns)
print(df.dtypes)
# Out:
# Index(['Gender', 'Age', 'Academic Pressure', 'Study Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Suicidal Thoughts', 'Study Hours',
#        'Financial Stress', 'Family History', 'Depression'],
#       dtype='object')
# Gender                 object
# Age                     int64
# Academic Pressure     float64
# Study Satisfaction    float64
# Sleep Duration         object
# Dietary Habits         object
# Suicidal Thoughts      object
# Study Hours             int64
# Financial Stress        int64
# Family History         object
# Depression             object
# dtype: object

# %% [markdown]
# ## Types of Columns:
# - Numerical Columns: Age, Academic Pressure, Study Satisfaction, Study Hours, Financial Stress,
# - Categorical Columns: Gender, Sleep Duration, Dietary Habits, Suicidal Thoughts, Family History, Depression
